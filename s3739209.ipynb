# %%
#Take 1: Data prepartion
# To load the data from csv file based on its format
automobile_p='automobile.csv'
import pandas as pd
automobile = pd.read_csv(automobile_p, sep='#', decimal='.',header=None, names=['symboling','normalized_losses','make','fuel_type','aspiration','num_of_doors','body_style','drive_wheels','engine_location','wheel_base','length','width','height','curb_weight','engine_type','num-of-cylinders','engine_size','fuel_system','bore','stroke','compression_ratio','horsepower','peak_rpm','city_mpg','highway_mpg','price'])

# %%
#go through the file object and show data type for each columns
automobile.dtypes
# Out:
# symboling              int64
# normalized_losses    float64
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num-of-cylinders      object
# engine_size            int64
# fuel_system           object
# bore                 float64
# stroke               float64
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
#display the first 10 rows of file : 
#user also can use y=automobile['COLUMN_NAME']
#or use: automobile:tail() to display table from bottom
automobile.head(10)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
# 5          2                NaN         audi       gas        std
# 6          1              158.0         audi       gas        std
# 7          1                NaN         audi       gas        std
# 8          1              158.0         audi       gas      turbo
# 9          0                NaN         audi       gas      turbo
#
#   num_of_doors   body_style drive_wheels engine_location  wheel_base   ...     \
# 0          two  convertible          rwd           front        88.6   ...
# 1          two  convertible          rwd           front        88.6   ...
# ...

# %%
#print shape of csv file
#it shows the table has 238 rows with 26 columns
print(automobile.shape)
# Out:
# (238, 26)

# %%
#make a copy of csv file
fake_automobile = automobile.copy()

# %%
fake_automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 26 columns):
# symboling            238 non-null int64
# normalized_losses    191 non-null float64
# make                 238 non-null object
# fuel_type            238 non-null object
# aspiration           238 non-null object
# num_of_doors         236 non-null object
# body_style           238 non-null object
# drive_wheels         238 non-null object
# engine_location      238 non-null object
# wheel_base           238 non-null float64
# length               238 non-null float64
# width                238 non-null float64
# height               238 non-null float64
# curb_weight          238 non-null int64
# engine_type          238 non-null object
# num-of-cylinders     238 non-null object
# engine_size          238 non-null int64
# fuel_system          238 non-null object
# bore                 234 non-null float64
# stroke               234 non-null float64
# ...

# %%
fake_automobile.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num_of_doors   body_style drive_wheels engine_location  wheel_base   ...     \
# 0          two  convertible          rwd           front        88.6   ...
# 1          two  convertible          rwd           front        88.6   ...
# 2          two    hatchback          rwd           front        94.5   ...
# 3         four        sedan          fwd           front        99.8   ...
# 4         four        sedan          4wd           front        99.4   ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
fake_automobile.iloc[200:212,:]
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 200         -1               95.0       volvo       gas        std
# 201         -1               95.0       volvo       gas      turbo
# 202         -1               95.0       volvo       gas        std
# 203         -1               95.0       volvo    diesel      turbo
# 204         -1               95.0       volvo       gas      turbo
# 205          4               25.0      volvo        gas        std
# 206         -1               95.0      volvo        gas      turbo
# 207         -1               95.0      volvo        gas        std
# 208         -1                NaN      volvo     diesel      turbo
# 209         -1                NaN  vol00112ov       gas      turbo
# 210         -1               95.0       volvo    diesel   turrrrbo
# 211         -1               95.0       volvo       gas      turbo
#
#     num_of_doors body_style drive_wheels engine_location  wheel_base   ...     \
# ...

# %%
#check the information for each columns, starts from object
fake_automobile['make'].value_counts()
# Out:
# toyota           32
# volvo            29
# mazda            17
# nissan           17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# peugot           10
# volvo             9
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# vol00112ov        3
#  volvo            3
# jaguar            3
# renault           2
# Peugot            1
# Nissan            1
# mercury           1
# Name: make, dtype: int64

# %%
#deal with issues that these column has : delete the space
fake_automobile['make'] = fake_automobile['make'].str.strip()
fake_automobile['make'].replace('Nissan','nissan',inplace=True)
fake_automobile['make'].replace('Peugot','peugot', inplace=True)
fake_automobile['make'].replace('vol00112ov','volvo',inplace=True)

# %%
fake_automobile['make'].value_counts()
# Out:
# volvo            44
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# peugot           11
# dodge             9
# bmw               8
# mercedes-benz     8
# plymouth          7
# audi              7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# alfa-romero       3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
#deal with column 'aspiration'
fake_automobile['aspiration'].value_counts()
# Out:
# std         175
# turbo        57
# turrrrbo      3
# Std           2
# std           1
# Name: aspiration, dtype: int64

# %%
fake_automobile['aspiration'] = fake_automobile['aspiration'].str.strip()
fake_automobile['aspiration'].replace('Std','std',inplace= True)
fake_automobile['aspiration'].replace('turrrrbo','turbo',inplace= True)

# %%
fake_automobile['aspiration'].value_counts()
# Out:
# std      178
# turbo     60
# Name: aspiration, dtype: int64

# %%
#deal with column 'num_of_doors'
fake_automobile['num_of_doors'].value_counts()
# Out:
# four     142
# two       89
# fourR      3
# Four       1
# four       1
# Name: num_of_doors, dtype: int64

# %%
fake_automobile['num_of_doors'] = fake_automobile['num_of_doors'].str.strip()
fake_automobile['num_of_doors'].replace('fourR','four',inplace= True)
fake_automobile['num_of_doors'].replace('Four','four',inplace= True)

# %%
fake_automobile['num_of_doors'].value_counts()
# Out:
# four    147
# two      89
# Name: num_of_doors, dtype: int64

# %%
#deal with column 'body_style'
fake_automobile['body_style'].value_counts()
# Out:
# sedan          124
# hatchback       70
# wagon           26
# hardtop          8
# convertible      6
# sedan            2
# Sedan            1
# Wagon            1
# Name: body_style, dtype: int64

# %%
fake_automobile['body_style'] = fake_automobile['body_style'].str.strip()
fake_automobile['body_style'].replace('sedan','sedan', inplace = True)
fake_automobile['body_style'].replace('Sendan','sedan', inplace = True)
fake_automobile['body_style'].replace('Wagon','wagon', inplace = True)
fake_automobile['body_style'].replace('Sedan','sedan', inplace = True)

# %%
fake_automobile['body_style'].value_counts()
# Out:
# sedan          127
# hatchback       70
# wagon           27
# hardtop          8
# convertible      6
# Name: body_style, dtype: int64

# %%
#deal with column 'drive_wheels'
fake_automobile['drive_wheels'].value_counts()
# Out:
# fwd     118
# rwd     108
# 4wd       9
# rwd       1
# fwd       1
# Fwd       1
# Name: drive_wheels, dtype: int64

# %%
fake_automobile['drive_wheels'] = fake_automobile['drive_wheels'].str.strip()
fake_automobile['drive_wheels'].replace('Fwd','fwd',inplace= True)

# %%
fake_automobile['drive_wheels'].value_counts()
# Out:
# fwd    120
# rwd    109
# 4wd      9
# Name: drive_wheels, dtype: int64

# %%
#deal with column 'engine_location'
fake_automobile['engine_location'].value_counts()
# Out:
# front     232
# Front       1
# REAR        1
# rear        1
# front       1
# FRONT       1
# Rear        1
# Name: engine_location, dtype: int64

# %%
fake_automobile['engine_location'] = fake_automobile['engine_location'].str.strip()
fake_automobile['engine_location'].replace('Front','front', inplace=True)
fake_automobile['engine_location'].replace('FRONT','front', inplace=True)
fake_automobile['engine_location'].replace('REAR','rear', inplace=True)
fake_automobile['engine_location'].replace('Rear','rear', inplace=True)

# %%
fake_automobile['engine_location'].value_counts()
# Out:
# front    235
# rear       3
# Name: engine_location, dtype: int64

# %%
#deal with column 'engine_type'
fake_automobile['engine_type'].value_counts()
# Out:
# ohc      175
# ohcv      18
# ohcf      15
# l         12
# dohc      12
# rotor      4
# Ohc        1
# dohcv      1
# Name: engine_type, dtype: int64

# %%
fake_automobile['engine_type'] = fake_automobile['engine_type'].str.strip()
fake_automobile['engine_type'].replace('Ohc','ohc',inplace=True)

# %%
fake_automobile['engine_type'].value_counts()
# Out:
# ohc      176
# ohcv      18
# ohcf      15
# l         12
# dohc      12
# rotor      4
# dohcv      1
# Name: engine_type, dtype: int64

# %%
#deal with column 'num-of-cylinders'
fake_automobile['num-of-cylinders'].value_counts()
# Out:
# four      175
# six        37
# five       10
# eight       5
# two         4
# Four        2
#  four       2
# five        1
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64

# %%
fake_automobile['num-of-cylinders'] = fake_automobile['num-of-cylinders'].str.strip()
fake_automobile['num-of-cylinders'].replace('Four','four',inplace=True)

# %%
fake_automobile['num-of-cylinders'].value_counts()
# Out:
# four      179
# six        37
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64

# %%
#deal with column 'fuel_system'
fake_automobile['fuel_system'].value_counts()
# Out:
# mpfi     116
# 2bbl      66
# idi       28
# 1bbl      11
# spdi       9
# 4bbl       3
# mpfi       2
# spfi       1
# Mpfi       1
# mfi        1
# Name: fuel_system, dtype: int64

# %%
fake_automobile['fuel_system'] = fake_automobile['fuel_system'].str.strip()
fake_automobile['fuel_system'].replace('Mpfi','mpfi',inplace=True)

# %%
fake_automobile['fuel_system'].value_counts()
# Out:
# mpfi    119
# 2bbl     66
# idi      28
# 1bbl     11
# spdi      9
# 4bbl      3
# spfi      1
# mfi       1
# Name: fuel_system, dtype: int64

# %%
#fake_automobile =fake_automobile.drop_duplicates()
fake_automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 26 columns):
# symboling            238 non-null int64
# normalized_losses    191 non-null float64
# make                 238 non-null object
# fuel_type            238 non-null object
# aspiration           238 non-null object
# num_of_doors         236 non-null object
# body_style           238 non-null object
# drive_wheels         238 non-null object
# engine_location      238 non-null object
# wheel_base           238 non-null float64
# length               238 non-null float64
# width                238 non-null float64
# height               238 non-null float64
# curb_weight          238 non-null int64
# engine_type          238 non-null object
# num-of-cylinders     238 non-null object
# engine_size          238 non-null int64
# fuel_system          238 non-null object
# bore                 234 non-null float64
# stroke               234 non-null float64
# ...

# %%
#after check the string type, 
#check the impossible value for Integer and float number
fake_automobile['symboling'].value_counts()
# Out:
#  0    67
#  1    54
# -1    52
#  2    32
#  3    27
#  4     3
# -2     3
# Name: symboling, dtype: int64

# %%
#because 4 is impossbile data for symoling.
fake_automobile[fake_automobile.symboling==4]
# Out:
#      symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 205          4               25.0  volvo       gas        std         four
# 218          4               25.0  volvo       gas        std         four
# 231          4               25.0  volvo       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base   ...     engine_size  \
# 205      sedan          rwd           front       109.1   ...             141
# 218      sedan          rwd           front       109.1   ...             141
# 231      sedan          rwd           front       109.1   ...             141
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 205         mpfi  3.78    3.15               9.5      114.0    5400.0
# 218         mpfi  3.78    3.15               9.5      114.0    5400.0
# 231         mpfi  3.78    3.15               9.5      114.0    5400.0
#
#     city_mpg  highway_mpg    price
# ...

# %%
#make the 4 become none value and assign value to  it
import numpy as np
fake_automobile.loc[fake_automobile.symboling ==4,'symboling'] = np.nan

fake_automobile['symboling'].fillna(-1,inplace =True)

# %%
fake_automobile[fake_automobile.make=='volvo']
# Out:
#      symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 194       -2.0              103.0  volvo       gas        std         four
# 195       -1.0               74.0  volvo       gas        std         four
# 196       -2.0              103.0  volvo       gas        std         four
# 197       -1.0               74.0  volvo       gas        std         four
# 198       -2.0              103.0  volvo       gas      turbo         four
# 199       -1.0               74.0  volvo       gas      turbo         four
# 200       -1.0               95.0  volvo       gas        std         four
# 201       -1.0               95.0  volvo       gas      turbo         four
# 202       -1.0               95.0  volvo       gas        std         four
# 203       -1.0               95.0  volvo    diesel      turbo         four
# 204       -1.0               95.0  volvo       gas      turbo         four
# ...

# %%
fake_automobile.iat[205,1]='95'
fake_automobile.iat[208,1]='95'
fake_automobile.iat[209,1]='95'
fake_automobile.iat[222,1]='95'
fake_automobile.iat[221,1]='95'
fake_automobile.iat[218,1]='95'
fake_automobile.iat[231,1]='95'
fake_automobile.iat[234,1]='95'
fake_automobile.iat[235,1]='95'
fake_automobile.iat[210,25]='22470.0'
fake_automobile.iat[211,25]='22625.0'
fake_automobile.iat[223,25]='22470.0'
fake_automobile.iat[224,25]='22625.0'
fake_automobile.iat[236,25]='22470.0'
fake_automobile.iat[237,25]='22625.0'

# %%
fake_automobile.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 233       -1.0               95.0  volvo       gas        std         four
# 234       -1.0               95.0  volvo    diesel      turbo         four
# 235       -1.0               95.0  volvo       gas      turbo         four
# 236       -1.0               95.0  volvo    diesel      turbo         four
# 237       -1.0               95.0  volvo       gas      turbo         four
#
#     body_style drive_wheels engine_location  wheel_base   ...     engine_size  \
# 233      sedan          rwd           front       109.1   ...             173
# 234      sedan          rwd           front       109.1   ...             145
# 235      sedan          rwd           front       109.1   ...             141
# 236      sedan          rwd           front       109.1   ...             145
# 237      sedan          rwd           front       109.1   ...             141
#
# ...

# %%
fake_automobile.drop_duplicates()
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0          3.0                NaN  alfa-romero       gas        std
# 1          3.0                NaN  alfa-romero       gas        std
# 2          1.0                NaN  alfa-romero       gas        std
# 3          2.0              164.0         audi       gas        std
# 4          2.0              164.0         audi       gas        std
# 5          2.0                NaN         audi       gas        std
# 6          1.0              158.0         audi       gas        std
# 7          1.0                NaN         audi       gas        std
# 8          1.0              158.0         audi       gas      turbo
# 9          0.0                NaN         audi       gas      turbo
# 10         2.0              192.0          bmw       gas        std
# 11         0.0              192.0          bmw       gas        std
# 12         0.0              188.0          bmw       gas        std
# ...

# %%
fake_automobile.isnull().sum(axis=0)
# Out:
# symboling             0
# normalized_losses    41
# make                  0
# fuel_type             0
# aspiration            0
# num_of_doors          2
# body_style            0
# drive_wheels          0
# engine_location       0
# wheel_base            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num-of-cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %%
#dealing with none value in number of doors
fake_automobile[fake_automobile.num_of_doors.isnull()]
# Out:
#     symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 27        1.0              148.0  dodge       gas      turbo          NaN
# 63        0.0                NaN  mazda    diesel        std          NaN
#
#    body_style drive_wheels engine_location  wheel_base   ...     engine_size  \
# 27      sedan          fwd           front        93.7   ...              98
# 63      sedan          fwd           front        98.8   ...             122
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 27         mpfi  3.03    3.39               7.6      102.0    5500.0       24
# 63          idi  3.39    3.39              22.7       64.0    4650.0       36
#
#     highway_mpg    price
# 27           30   8558.0
# 63           42  10795.0
#
# [2 rows x 26 columns]

# %%
#since the table show body_style is sedan, the num_of_doors should be 4
fake_automobile.iat[27,5]='four'
fake_automobile.iat[63,5]='four'

# %%
fake_automobile[fake_automobile.num_of_doors.isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#fill the non-value in normalized_losses column and convert it to int data type
#fake_automobile['normalized_losses'].fillna(fake_automobile['normalized_losses'].mean(axis=0),inplace=True)
import numpy as np
nl=fake_automobile['normalized_losses'].loc[fake_automobile['normalized_losses'].notnull()]
nlmean = nl.astype(int).mean();
fake_automobile['normalized_losses']=fake_automobile['normalized_losses'].replace(np.nan,nlmean).astype(int)

# %%
fake_automobile.head(20)
# Out:
#     symboling  normalized_losses         make fuel_type aspiration  \
# 0         3.0                117  alfa-romero       gas        std
# 1         3.0                117  alfa-romero       gas        std
# 2         1.0                117  alfa-romero       gas        std
# 3         2.0                164         audi       gas        std
# 4         2.0                164         audi       gas        std
# 5         2.0                117         audi       gas        std
# 6         1.0                158         audi       gas        std
# 7         1.0                117         audi       gas        std
# 8         1.0                158         audi       gas      turbo
# 9         0.0                117         audi       gas      turbo
# 10        2.0                192          bmw       gas        std
# 11        0.0                192          bmw       gas        std
# 12        0.0                188          bmw       gas        std
# ...

# %%
#deal with column 'wheel-base' to see if any impossible value
x=fake_automobile[['wheel_base']]
x.head()
# Out:
#    wheel_base
# 0        88.6
# 1        88.6
# 2        94.5
# 3        99.8
# 4        99.4

# %%
#check impossible number for wheel_base from 86.6 to 120.9
fake_automobile[(fake_automobile.wheel_base<86.6)|(fake_automobile.wheel_base>120.9)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'length' to see if any impossible value
fake_automobile[['length']].head()
# Out:
#    length
# 0   168.8
# 1   168.8
# 2   171.2
# 3   176.6
# 4   176.6

# %%
#check impossible number for length from 141.1 to 208.1
fake_automobile[(fake_automobile.length<141.1)|(fake_automobile.length>208.1)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'width' to see if any impossible value
fake_automobile[['width']].head()
# Out:
#    width
# 0   64.1
# 1   64.1
# 2   65.5
# 3   66.2
# 4   66.4

# %%
#check impossible number for width from 60.3 to 72.3
fake_automobile[(fake_automobile.width<60.3)|(fake_automobile.width>72.3)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'height' to see if any impossible value
fake_automobile[['height']].head()
# Out:
#    height
# 0    48.8
# 1    48.8
# 2    52.4
# 3    54.3
# 4    54.3

# %%
#check impossible number for width from 47.8 to 59.8
fake_automobile[(fake_automobile.height<47.8)|(fake_automobile.height>59.8)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'curb-weight' to see if any impossible value
fake_automobile[['curb_weight']].head()
# Out:
#    curb_weight
# 0         2548
# 1         2548
# 2         2823
# 3         2337
# 4         2824

# %%
#check impossible number for curb_weight from 1488 to 4066
fake_automobile[(fake_automobile.curb_weight<1488)|(fake_automobile.curb_weight>4066)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'engin-size' to see if any impossible value
fake_automobile[['engine_size']].head()
# Out:
#    engine_size
# 0          130
# 1          130
# 2          152
# 3          109
# 4          136

# %%
#check impossible number for engine_size from 61 to 326
fake_automobile[(fake_automobile.engine_size<61)|(fake_automobile.engine_size>326)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'bore' to see if any impossible value
fake_automobile[['bore']].head()
# Out:
#    bore
# 0  3.47
# 1  3.47
# 2  2.68
# 3  3.19
# 4  3.19

# %%
#check impossible number for bore from 2.54 to 3.94
fake_automobile[(fake_automobile.bore<2.54)|(fake_automobile.bore>3.94)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#check the null value in bore column
fake_automobile[fake_automobile.bore.isnull()]
# Out:
#     symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 55        3.0                150  mazda       gas        std          two
# 56        3.0                150  mazda       gas        std          two
# 57        3.0                150  mazda       gas        std          two
# 58        3.0                150  mazda       gas        std          two
#
#    body_style drive_wheels engine_location  wheel_base   ...     engine_size  \
# 55  hatchback          rwd           front        95.3   ...              70
# 56  hatchback          rwd           front        95.3   ...              70
# 57  hatchback          rwd           front        95.3   ...              70
# 58  hatchback          rwd           front        95.3   ...              80
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 55         4bbl   NaN     NaN               9.4      101.0    6000.0       17
# ...

# %%
#fill the null value with mean
fake_automobile['bore'].fillna(fake_automobile['bore'].mean(axis=0),inplace=True)

# %%
fake_automobile[fake_automobile.bore.isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'stroke' to see if any impossible value
fake_automobile[['stroke']].head()
# Out:
#    stroke
# 0    2.68
# 1    2.68
# 2    3.47
# 3    3.40
# 4    3.40

# %%
#check impossible number for stroke from 2.07 to 4.17
fake_automobile[(fake_automobile.stroke<2.07)|(fake_automobile.stroke>4.17)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#check the null value in stroke column
fake_automobile[fake_automobile.stroke.isnull()]
# Out:
#     symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 55        3.0                150  mazda       gas        std          two
# 56        3.0                150  mazda       gas        std          two
# 57        3.0                150  mazda       gas        std          two
# 58        3.0                150  mazda       gas        std          two
#
#    body_style drive_wheels engine_location  wheel_base   ...     engine_size  \
# 55  hatchback          rwd           front        95.3   ...              70
# 56  hatchback          rwd           front        95.3   ...              70
# 57  hatchback          rwd           front        95.3   ...              70
# 58  hatchback          rwd           front        95.3   ...              80
#
#     fuel_system      bore  stroke compression_ratio horsepower  peak_rpm  \
# 55         4bbl  3.361282     NaN               9.4      101.0    6000.0
# ...

# %%
#fill the null value with mean
fake_automobile['stroke'].fillna(fake_automobile['stroke'].mean(axis=0),inplace=True)

# %%
fake_automobile[fake_automobile.stroke.isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'compression_ratio' to see if any impossible value
fake_automobile[['compression_ratio']].head()
# Out:
#    compression_ratio
# 0                9.0
# 1                9.0
# 2                9.0
# 3               10.0
# 4                8.0

# %%
#check impossible number for compression_ratio from 7 to 23
fake_automobile[(fake_automobile.compression_ratio<7)|(fake_automobile.compression_ratio>23)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'horsepower' to see if any impossible value
fake_automobile[['horsepower']].head()
# Out:
#    horsepower
# 0       111.0
# 1       111.0
# 2       154.0
# 3       102.0
# 4       115.0

# %%
#check impossible number for horsepower from 48 to 288
fake_automobile[(fake_automobile.horsepower<48)|(fake_automobile.horsepower>288)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#check the null value in stroke column
fake_automobile[fake_automobile.horsepower.isnull()]
# Out:
#      symboling  normalized_losses     make fuel_type aspiration num_of_doors  \
# 130        0.0                117  renault       gas        std         four
# 131        2.0                117  renault       gas        std          two
#
#     body_style drive_wheels engine_location  wheel_base   ...    engine_size  \
# 130      wagon          fwd           front        96.1   ...            132
# 131  hatchback          fwd           front        96.1   ...            132
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 130         mpfi  3.46     3.9               8.7        NaN       NaN
# 131         mpfi  3.46     3.9               8.7        NaN       NaN
#
#     city_mpg  highway_mpg   price
# 130       23           31  9295.0
# 131       23           31  9895.0
#
# [2 rows x 26 columns]

# %%
#fill the null value with mean
#fake_automobile['horsepower'].fillna(fake_automobile['horsepower'].mean(axis=0),inplace=True)
nl=fake_automobile['horsepower'].loc[fake_automobile['horsepower'].notnull()]
nlmean = nl.astype(int).mean();
fake_automobile['horsepower']=fake_automobile['horsepower'].replace(np.nan,nlmean).astype(int)

# %%
fake_automobile[fake_automobile.horsepower.isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column 'peak-rpm' to see if any impossible value
fake_automobile[['peak_rpm']].head()
# Out:
#    peak_rpm
# 0    5000.0
# 1    5000.0
# 2    5000.0
# 3    5500.0
# 4    5500.0

# %%
#check impossible number for peak_rpm from 4150 to 6600
fake_automobile[(fake_automobile.peak_rpm<4150)|(fake_automobile.peak_rpm>6600)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#check the null value in peak_rpm column
fake_automobile[fake_automobile.peak_rpm.isnull()]
# Out:
#      symboling  normalized_losses     make fuel_type aspiration num_of_doors  \
# 130        0.0                117  renault       gas        std         four
# 131        2.0                117  renault       gas        std          two
#
#     body_style drive_wheels engine_location  wheel_base   ...    engine_size  \
# 130      wagon          fwd           front        96.1   ...            132
# 131  hatchback          fwd           front        96.1   ...            132
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 130         mpfi  3.46     3.9               8.7        107       NaN
# 131         mpfi  3.46     3.9               8.7        107       NaN
#
#     city_mpg  highway_mpg   price
# 130       23           31  9295.0
# 131       23           31  9895.0
#
# [2 rows x 26 columns]

# %%
#fill the null value with mean
#fake_automobile['peak_rpm'].fillna(fake_automobile['peak_rpm'].mean(axis=0),inplace=True)
#fake_automobile['peak_rpm'].fillna(0,inplace=True)
nl=fake_automobile['peak_rpm'].loc[fake_automobile['peak_rpm'].notnull()]
nlmean = nl.astype(int).mean();
fake_automobile['peak_rpm']=fake_automobile['peak_rpm'].replace(np.nan,nlmean).astype(int)

# %%
fake_automobile[fake_automobile.peak_rpm.isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column city-mpg to see if any impossible value
fake_automobile[['city_mpg']].head()
# Out:
#    city_mpg
# 0        21
# 1        21
# 2        19
# 3        24
# 4        18

# %%
#check impossible number for city_mpg from 13 to 49
fake_automobile[(fake_automobile.city_mpg<13)|(fake_automobile.city_mpg>49)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column highway-mpg to see if any impossible value
fake_automobile[['highway_mpg']].head()
# Out:
#    highway_mpg
# 0           27
# 1           27
# 2           26
# 3           30
# 4           22

# %%
#check impossible number for highway-mpg from 16 to 54
fake_automobile[(fake_automobile.highway_mpg<16)|(fake_automobile.highway_mpg>54)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#deal with column price to see if any impossible value
fake_automobile[['price']].head()
# Out:
#      price
# 0  13495.0
# 1  16500.0
# 2  16500.0
# 3  13950.0
# 4  17450.0

# %%
#check impossible number for price from 5118 to 45400
fake_automobile[(fake_automobile.price<5118)|(fake_automobile.price>45400)]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#check the null value in peak_rpm column
fake_automobile[fake_automobile.price.isnull()]
# Out:
#      symboling  normalized_losses     make fuel_type aspiration num_of_doors  \
# 9          0.0                117     audi       gas      turbo          two
# 44         1.0                117    isuzu       gas        std          two
# 45         0.0                117    isuzu       gas        std         four
# 129        1.0                117  porsche       gas        std          two
#
#     body_style drive_wheels engine_location  wheel_base  ...    engine_size  \
# 9    hatchback          4wd           front        99.5  ...            131
# 44       sedan          fwd           front        94.5  ...             90
# 45       sedan          fwd           front        94.5  ...             90
# 129  hatchback          rwd           front        98.4  ...            203
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 9           mpfi  3.13    3.40               7.0        160      5500
# ...

# %%
#fill the null value with mean
nl=fake_automobile['price'].loc[fake_automobile['price'].notnull()]
nlmean = nl.astype(int).mean();
fake_automobile['price']=fake_automobile['price'].replace(np.nan,nlmean).astype(int)

# %%
fake_automobile[fake_automobile.price.isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num-of-cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
#convet symboling to int
fake_automobile['symboling'] =fake_automobile['symboling'].astype('int')
fake_automobile['compression_ratio'] =fake_automobile['compression_ratio'].astype('int')

# %%
#the data type changed based on the specification
fake_automobile.dtypes
# Out:
# symboling              int32
# normalized_losses      int32
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num-of-cylinders      object
# engine_size            int64
# fuel_system           object
# bore                 float64
# stroke               float64
# compression_ratio      int32
# horsepower             int32
# peak_rpm               int32
# city_mpg               int64
# highway_mpg            int64
# price                  int32
# dtype: object

# %%
#fake_automobile convert to csv.file where stored clean data
fake_automobile.to_csv('AutomobileClean.csv')

# %%
fake_automobile.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 233         -1                 95  volvo       gas        std         four
# 234         -1                 95  volvo    diesel      turbo         four
# 235         -1                 95  volvo       gas      turbo         four
# 236         -1                 95  volvo    diesel      turbo         four
# 237         -1                 95  volvo       gas      turbo         four
#
#     body_style drive_wheels engine_location  wheel_base  ...    engine_size  \
# 233      sedan          rwd           front       109.1  ...            173
# 234      sedan          rwd           front       109.1  ...            145
# 235      sedan          rwd           front       109.1  ...            141
# 236      sedan          rwd           front       109.1  ...            145
# 237      sedan          rwd           front       109.1  ...            141
#
# ...

# %%
fake_automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 26 columns):
# symboling            238 non-null int32
# normalized_losses    238 non-null int32
# make                 238 non-null object
# fuel_type            238 non-null object
# aspiration           238 non-null object
# num_of_doors         238 non-null object
# body_style           238 non-null object
# drive_wheels         238 non-null object
# engine_location      238 non-null object
# wheel_base           238 non-null float64
# length               238 non-null float64
# width                238 non-null float64
# height               238 non-null float64
# curb_weight          238 non-null int64
# engine_type          238 non-null object
# num-of-cylinders     238 non-null object
# engine_size          238 non-null int64
# fuel_system          238 non-null object
# bore                 238 non-null float64
# stroke               238 non-null float64
# ...

# %%
# Task 2: Data Exploration
# 1. Choose 1 column with nominal values, 1 column with ordinal Values, and 1 column with numerical values
import matplotlib.pyplot as plt

# %%
#for the nominal values, we select make 
d_make = {'make': fake_automobile.make}
d_make = d_make['make'].value_counts().reset_index()
d_make.columns = ['make','count']
d_m=pd.DataFrame(d_make)
d_m.plot(kind='bar',x='make',y='count')
plt.title('Automobile - Make info')
plt.ylabel('number')
plt.show()
#The bar graph shows how many cars for each brand tested in this data set

# %%
#ordnial value ---symboling
#the pie chart shows that the percentage of each symoboling rate in dataset
fake_automobile['symboling'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(6,6))
plt.title('Automobile - Symboling info')
plt.show()

# %%
#numerical value --normalized losses
#The density graphy shows the density of normalized losses in dataset, which is between 65 to 256
fake_automobile['normalized_losses'].plot(kind='density')
plt.title('automobile -Normalize-losses info')
plt.xlabel('Normalize-losses')
plt.show()

# %%
# Task 2: Data Exploration
# 2. Explore the relationships between columns; at least 3 visualisations with plausible hypothesis
# The first pair - Symboling rate & num_of_doors
fake_automobile.groupby(['num_of_doors']).mean()
# Out:
#               symboling  normalized_losses  wheel_base      length      width  \
# num_of_doors
# four          -0.134228         107.369128  102.783893  180.553020  66.832886
# two            1.775281         133.707865   95.741573  168.630337  65.424719
#
#                  height  curb_weight  engine_size      bore    stroke  \
# num_of_doors
# four          55.042953  2739.073826   131.563758  3.399262  3.234631
# two           52.221348  2442.471910   126.247191  3.297698  3.257331
#
#               compression_ratio  horsepower     peak_rpm   city_mpg  \
# num_of_doors
# four                  10.785235  105.416107  5072.080537  24.228188
# two                    9.067416  110.056180  5256.067416  25.325843
#
#               highway_mpg         price
# num_of_doors
# four            29.402685  15114.651007
# two             31.044944  12867.202247

# %%
#all in all symboling
fake_automobile['symboling'].plot(kind='box')
plt.show ()

# %%
#boxplot for symboling that group by num_of_doors
fake_automobile.dropna().boxplot(column='symboling',by='num_of_doors')
plt.title('')
plt.ylabel('symboling')
plt.show()

# %%
#The sencond pair -- price & symboling
import seaborn as sns
graph = sns.lmplot('symboling','price',fake_automobile)
graph.fig.suptitle('Plot bewteen price & symboling')
# Out:
# D:\Anaconda2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,0.98,'Plot bewteen price & symboling')

# %%
#The third pair --curb-weight & highway mileage
graph = sns.lmplot("curb_weight",'highway_mpg', fake_automobile, hue="make",fit_reg=False);
graph.fig.suptitle('Plot bewteen curb weight & highway milegae')
# Out:
# Text(0.5,0.98,'Plot bewteen curb weight & highway milegae')

# %%
# Task 2: Data Exploration
# 3. Scatter matrix for all numerical columns
from pandas.plotting import scatter_matrix
scatter_matrix(fake_automobile,alpha=0.2,figsize=(32,32),diagonal='hist')
plt.show()
